# %%
# Nomor 5
# Looping tanpa Henti

i = 0
while i < i + 2:
  i += 1
  print("*")
else:
  print("*")

# %%
# Nomor 6
# Output?

lst = [1, 2]

for v in range(2):
  lst.insert(-1, lst[v])

print(lst)
# Out:
# [1, 1, 1, 2]

# %%
# Nomor 7
# Banyak Elemen lst?

lst = [i for i in range(-1, -2)]
print(lst)
# Out:
# []

# %%
# Nomor 8 - Operator Pembagian Bulat
# Output?

num = 1 // 2
print(num)
# Out:
# 0

# %%
# Nomor 9
# Pernyataan sesuai?

nums = [1, 2, 3]
vals = nums
del vals[:]

# %%
# Nomor 10
# Output Variable X?

z = 0
y = 10
x = y < z and z > y or y > z and z < y
print(x)
# Out:
# True

# %%
# Nomor 11
# Input User 5 dan 6?

y = input()
x = input()
print(x + y)
# Out:
# 5
# 6
# 65

# %%
# Nomor 13
# Output?

x = 1
y = 2
x, y, z = x, x, y
z, y, z = x, y, z

print(x, y, z)
# Out:
# 1 1 2

# %%
# Nomor 14
# Output?

tup = (1, 2, 4, 8)
tup = tup[-2:-1]
tup = tup[-1]
print(tup)
# Out:
# 4

# %%
# Nomor 16
# Lengkapi src

fruits = ['apel', 'pisang', 'jeruk']
fruits.append('anggur')
print(fruits)
fruits[0] = 'ceri'
print(fruits[0])
# Out:
# ['apel', 'pisang', 'jeruk', 'anggur']
# ceri

# %%
# Nomor 17
# Lengkapi src

fruits = {'apel': 1, 'pisang': 2, 'jeruk': 4}
print(fruits)
fruits['pisang'] = 3
print(fruits)
fruits1 = {'anggur': 5}
fruits.update(fruits1)
print(fruits)
# Out:
# {'apel': 1, 'pisang': 2, 'jeruk': 4}
# {'apel': 1, 'pisang': 3, 'jeruk': 4}
# {'apel': 1, 'pisang': 3, 'jeruk': 4, 'anggur': 5}

# %%
# Nomor 18
# Perbaiki Program

def move(n, x, y, z):
  if n == 1:
    print("Pindah kelas " + x + " ke " + y)
    return
  move(n-1, x, z, y)
  move(n-1, x, y, z)
  move(n-1, y, x, z)

move(3, 'A', 'C', 'B')
# Out:
# Pindah kelas A ke C
# Pindah kelas A ke B
# Pindah kelas B ke A
# Pindah kelas A ke B
# Pindah kelas A ke C
# Pindah kelas C ke A
# Pindah kelas C ke B
# Pindah kelas C ke A
# Pindah kelas A ke C

# %%
# Recursive Python function to solve the tower of hanoi 

def TowerOfHanoi(n , source, destination, auxiliary): 
	if n==1: 
		print "Move disk 1 from source",source,"to destination",destination 
		return
	TowerOfHanoi(n-1, source, auxiliary, destination) 
	print "Move disk",n,"from source",source,"to destination",destination 
	TowerOfHanoi(n-1, auxiliary, destination, source) 
		
# Driver code 
n = 4
TowerOfHanoi(n,'A','B','C') 
# A, C, B are the name of rods
# Out:
#   File "<ipython-input-17-bd20469b7128>", line 5
#     print "Move disk 1 from source",source,"to destination",destination
#                                   ^
# SyntaxError: Missing parentheses in call to 'print'. Did you mean print("Move disk 1 from source",source,"to destination",destination)?

# %%
# Nomor 19
# Find Even Number?

input = [1, 2, 3, 4, 5, 6, 7, 8, 9]  
output = [num for num in input if num % 2 == 0] 
print(output)
# Out:
# [2, 4, 6, 8]

# %%
# Nomor 20 - Double Asterix
# Gabung Dictionary

dic1 = {1: 20, 2: 20}
dic2 = {3: 30, 4: 40}
dic3 = {5: 50, 6: 60}
dic4 = {**dic1, **dic2, **dic3}
print(dic4)
# Out:
# {1: 20, 2: 20, 3: 30, 4: 40, 5: 50, 6: 60}
